# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Exercise 4.7 - Code along

# %%
ords_prods_merge = pd.read_pickle(r"C:\Users\Windows\Instacart Basket Analysis\02 Data\Prepared Data\ords_prods_merge.pkl")

# %%
df = ords_prods_merge[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.shape
# Out:
# (1000000, 13)

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_1384\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['prices'].max()
# Out:
# 24.5

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: price_range, dtype: int64

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_1384\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day_ordered  \
# 0   3139998      138            28                   6                   11
# 1   1977647      138            30                   6                   17
# 2    389851      709             2                   0                   21
# 3    652770      764             1                   3                   13
# 4   1813452      764             3                   4                   17
#
# ...

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# ## Task 4.7 Begins

# %% [markdown]
# ### Step 1b  - see above
#
# ### Step 1a - see the end of the file. Please note my Jupyter crashed a few times. I decided to moved forward with adding the "busiest_day" column before going back to categorizing the price range.

# %% [markdown]
# ### Steps 2 & 3

# %%
# Step 2
col_1 = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value ==1:
    col_1.append("Busiest day")
  elif value == 3 or value == 4:
    col_1.append("Slowest day")
  else:
    col_1.append("Regularly busy")

# %%
ords_prods_merge['busiest_days'] = col_1

# %%
col_1
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Slowest day',
#  'Slowest day',
#  'Busiest day',
#  'Regularly busy',
#  'Slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Slowest day',
#  'Slowest day',
#  'Regularly busy',
#  'Slowest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Slowest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Slowest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Slowest day',
#  'Regularly busy',
# ...

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day_ordered  \
# 0   3139998      138            28                   6                   11
# 1   1977647      138            30                   6                   17
# 2    389851      709             2                   0                   21
# 3    652770      764             1                   3                   13
# 4   1813452      764             3                   4                   17
#
# ...

# %% [markdown]
# ####  Step 3
#
# ##### In the new column, what used to be "regularly busy", which falls on day 3  is now one of the two slowest days.  Also, what used to be "least busy" day, which falls on day 4, is now the other slowest day.  Day = 0 remains the busiest day. Day 6 or Sunday remains "regularly busy".  These results are consistent with the logic set up in the if-then statement used to create this new column "busiest_days".

# %% [markdown]
# ### Steps 4 & 5

# %%
ords_prods_merge['hour_of_day_ordered'].value_counts(dropna=False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: hour_of_day_ordered, dtype: int64

# %%
col_2 = []

for value in ords_prods_merge["hour_of_day_ordered"]:
  if value in [10, 11,14,15,13,12,16,9,17]:
    col_2.append("Most orders")
  elif value in [2,3,4,5]:
    col_2.append("Fewest orders")
  else:
    col_2.append("Average orders")

# %%
col_2
# Out:
# ['Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
ords_prods_merge['busiest_period_of_day'] = col_2

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most orders       23205725
# Average orders     8937275
# Fewest orders       261859
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day_ordered  \
# 0   3139998      138            28                   6                   11
# 1   1977647      138            30                   6                   17
# 2    389851      709             2                   0                   21
# 3    652770      764             1                   3                   13
# 4   1813452      764             3                   4                   17
#
# ...

# %% [markdown]
# ### Step 1a - Add a column with price range

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day_ordered  \
# 0   3139998      138            28                   6                   11
# 1   1977647      138            30                   6                   17
# 2    389851      709             2                   0                   21
# 3    652770      764             1                   3                   13
# 4   1813452      764             3                   4                   17
#
# ...

# %%
# dropping the column"busiest_day" since a new column "businest_days" was created to replace it.
ords_prods_merge = ords_prods_merge.drop(columns = ['busiest_day'])

# %%
# checking memory usage.Jupyter has crashed multiple times, so I decided to see which variables types can be changed.
#the following few steps in this notebook show how I have changed some variable types to speed up Jupyter and avoid further crashes
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int64
#  1   product_name            object
#  2   aisle_id                int64
#  3   department_id           int64
#  4   prices                  float64
#  5   order_id                int32
#  6   user_id                 int32
#  7   order_number            int8
#  8   orders_day_of_week      int8
#  9   hour_of_day_ordered     int8
#  10  days_since_prior_order  float16
#  11  add_to_cart_order       int32
#  12  reordered               int8
#  13  busiest_days            object
#  14  busiest_period_of_day   object
#  15  price_range_loc         object
# dtypes: float16(1), float64(1), int32(3), int64(3), int8(4), object(4)
# memory usage: 2.7+ GB

# %%
# checking the variables in dataset
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day_ordered  \
# 0   3139998      138            28                   6                   11
# 1   1977647      138            30                   6                   17
# 2    389851      709             2                   0                   21
# 3    652770      764             1                   3                   13
# 4   1813452      764             3                   4                   17
#
# ...

# %%
# checking the max and min within each numerical variable to determine integer type in order to be memory efficient

ords_prods_merge.describe()
# Out:
#          product_id      aisle_id  department_id        prices      order_id  \
# count  3.240486e+07  3.240486e+07   3.240486e+07  3.240486e+07  3.240486e+07
# mean   2.559866e+04  7.119612e+01   9.919792e+00  1.198023e+01  1.710745e+06
# std    1.408400e+04  3.821139e+01   6.281485e+00  4.956554e+02  9.872988e+05
# min    1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00  2.000000e+00
# 25%    1.354400e+04  3.100000e+01   4.000000e+00  4.200000e+00  8.559470e+05
# 50%    2.530200e+04  8.300000e+01   9.000000e+00  7.400000e+00  1.711049e+06
# 75%    3.794700e+04  1.070000e+02   1.600000e+01  1.130000e+01  2.565499e+06
# max    4.968800e+04  1.340000e+02   2.100000e+01  9.999900e+04  3.421083e+06
#
#             user_id  order_number  orders_day_of_week  hour_of_day_ordered  \
# count  3.240486e+07  3.240486e+07        3.240486e+07         3.240486e+07
# mean   1.029372e+05  1.714230e+01        2.738867e+00         1.342515e+01
# ...

# %%
# changing variable types. These variables can updated to more efficient types

ords_prods_merge['price_range_loc']=ords_prods_merge['price_range_loc'].astype('category')
ords_prods_merge['busiest_days']=ords_prods_merge['busiest_days'].astype('category')
ords_prods_merge['busiest_period_of_day']=ords_prods_merge['busiest_period_of_day'].astype('category')
ords_prods_merge['department_id']=ords_prods_merge['department_id'].astype('int8')
ords_prods_merge['aisle_id']=ords_prods_merge['department_id'].astype('int16')
ords_prods_merge['add_to_cart_order']=ords_prods_merge['add_to_cart_order'].astype('int16')

# %%
# checking variable types
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int64
#  1   product_name            object
#  2   aisle_id                int16
#  3   department_id           int8
#  4   prices                  float64
#  5   order_id                int32
#  6   user_id                 int32
#  7   order_number            int8
#  8   orders_day_of_week      int8
#  9   hour_of_day_ordered     int8
#  10  days_since_prior_order  float16
#  11  add_to_cart_order       int16
#  12  reordered               int8
#  13  busiest_days            category
#  14  busiest_period_of_day   category
#  15  price_range_loc         category
# dtypes: category(3), float16(1), float64(1), int16(2), int32(2), int64(1), int8(5), object(1)
# memory usage: 1.6+ GB

# %%
# changing another variable type to reduce memory further 
ords_prods_merge['product_id']=ords_prods_merge['product_id'].astype('int32')

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int32
#  1   product_name            object
#  2   aisle_id                int16
#  3   department_id           int8
#  4   prices                  float64
#  5   order_id                int32
#  6   user_id                 int32
#  7   order_number            int8
#  8   orders_day_of_week      int8
#  9   hour_of_day_ordered     int8
#  10  days_since_prior_order  float16
#  11  add_to_cart_order       int16
#  12  reordered               int8
#  13  busiest_days            category
#  14  busiest_period_of_day   category
#  15  price_range_loc         category
# dtypes: category(3), float16(1), float64(1), int16(2), int32(3), int8(5), object(1)
# memory usage: 1.5+ GB

# %%
# Again, changing another variable type to reduce memory further 

ords_prods_merge['product_name']=ords_prods_merge['product_name'].astype('category')

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int32
#  1   product_name            category
#  2   aisle_id                int16
#  3   department_id           int8
#  4   prices                  float64
#  5   order_id                int32
#  6   user_id                 int32
#  7   order_number            int8
#  8   orders_day_of_week      int8
#  9   hour_of_day_ordered     int8
#  10  days_since_prior_order  float16
#  11  add_to_cart_order       int16
#  12  reordered               int8
#  13  busiest_days            category
#  14  busiest_period_of_day   category
#  15  price_range_loc         category
# dtypes: category(4), float16(1), float64(1), int16(2), int32(3), int8(5)
# memory usage: 1.4 GB

# %% [markdown]
# ### Steps 6 & 7

# %%
path = r"C:\Users\Windows\Instacart Basket Analysis"

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge1.pkl'))

# %% [markdown]
# ## Section 1 - Importing Python Libraries

# %%
#Import libraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Section 2 - Python Data Types

# %%
50+50
# Out:
# 100

# %%
300-200
# Out:
# 100

# %%
50+35+15
# Out:
# 100

# %%
a = 3.5 
b = 0.7 
a/b
# Out:
# 5.0

# %%
a= 'deli'
b= 'cious'
a+b
# Out:
# 'delicious'

# %%
a="What a wonderful"
b=" day!"

# %% [markdown]
# ## Bonus

# %%
a="apple"

# %%
a*100
# Out:
# '...'
